# %%
# %pip install structlog
# %pip install opencensus-ext-azure
# %pip install python-dotenv
# %pip install -U structlog azure-monitor-opentelemetry python-dotenv

# %% [markdown]
# ## AzureLogHandler

# %%
import os
from dotenv import load_dotenv
import structlog
from opencensus.ext.azure.log_exporter import AzureLogHandler
import logging

load_dotenv(".env")

logging.basicConfig(level=logging.DEBUG, force=True)

logger = structlog.get_logger()
connection_string = os.getenv("APPLICATIONINSIGHTS_CONNECTION_STRING")

# %%
# ロギング設定
logger = logging.getLogger("ApplicationInsights")
handler = AzureLogHandler(connection_string=connection_string)
logger.addHandler(handler)

# ログの送信例
logger.info("This is an INFO log sent to Azure Application Insights")
logger.warning("This is a WARNING log sent to Azure Application Insights")
logger.error("This is an ERROR log sent to Azure Application Insights")
# Out:
# INFO:ApplicationInsights:This is an INFO log sent to Azure Application Insights
# WARNING:ApplicationInsights:This is a WARNING log sent to Azure Application Insights
# ERROR:ApplicationInsights:This is an ERROR log sent to Azure Application Insights
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None

# %%
try:
    # 例外を発生させるコード
    raise UnicodeDecodeError("utf-8", b"", 1, 2, "test")
except Exception as e:
    logger.exception("UnicodeDecodeError", exc_info=True)
# Out:
# ERROR:ApplicationInsights:UnicodeDecodeError
# Traceback (most recent call last):
#   File "/var/folders/27/6hk2mfzs5vv9ysvns0ydhx2m0000gn/T/ipykernel_9744/52819273.py", line 3, in <module>
#     raise UnicodeDecodeError("utf-8", b"", 1, 2, "test")
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 1-1: test
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): japaneast-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://japaneast-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None

# %% [markdown]
# ## structlog + AzureLogHandler

# %%
import os
from dotenv import load_dotenv
import structlog
from opencensus.ext.azure.log_exporter import AzureLogHandler
import logging
from opencensus.ext.azure.log_exporter import AzureLogHandler
from opencensus.ext.azure.log_exporter import AzureEventHandler

load_dotenv(".env")

logging.basicConfig(level=logging.DEBUG, force=True)

logger = structlog.get_logger()
connection_string = os.getenv("APPLICATIONINSIGHTS_CONNECTION_STRING")

# 既存のロギングハンドラーをクリア
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# ロガーの作成
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# コンソールハンドラーの作成
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)

# Azure Log Handlerの作成
azure_handler = AzureLogHandler(connection_string=connection_string)
azure_handler.setLevel(logging.DEBUG)


# Telemetry Processorを定義してoperation_nameを設定
def set_operation_name(envelope):
    envelope.tags["ai.operation.name"] = "logger_test"


# Telemetry Processorをハンドラーに追加§
azure_handler.add_telemetry_processor(set_operation_name)

# structlogのProcessorFormatterを定義
# コンソールハンドラー用（色付き）
console_formatter = structlog.stdlib.ProcessorFormatter(
    processor=structlog.dev.ConsoleRenderer(colors=True),
    foreign_pre_chain=[
        structlog.processors.TimeStamper(fmt="iso"),
        structlog.stdlib.add_log_level,
        structlog.processors.ExceptionPrettyPrinter(),
    ],
)

# Azureハンドラー用（JSON形式）
azure_formatter = structlog.stdlib.ProcessorFormatter(
    processor=structlog.processors.JSONRenderer(),
    foreign_pre_chain=[
        structlog.processors.TimeStamper(fmt="iso"),
        structlog.stdlib.add_log_level,
        structlog.processors.StackInfoRenderer(),
        structlog.processors.format_exc_info,
    ],
)

# ハンドラーにフォーマッターを設定
console_handler.setFormatter(console_formatter)
azure_handler.setFormatter(azure_formatter)

# ロガーにハンドラーを追加
logger.addHandler(console_handler)
logger.addHandler(azure_handler)

# structlogの設定
structlog.configure(
    processors=[
        structlog.stdlib.add_logger_name,
        structlog.stdlib.add_log_level,
        structlog.processors.CallsiteParameterAdder(
            parameters=[
                structlog.processors.CallsiteParameter.FILENAME,  # Adds the filename
                structlog.processors.CallsiteParameter.LINENO,  # Adds the line number
            ]
        ),
        structlog.processors.TimeStamper(fmt="iso"),
        structlog.processors.StackInfoRenderer(),
        structlog.stdlib.ProcessorFormatter.wrap_for_formatter,
    ],
    logger_factory=structlog.stdlib.LoggerFactory(),
)

# structlogロガーの取§§
logger = structlog.get_logger()

# %%
# 使用例
logger.info("struct-test-info", data={"id": 1}, path="/path/to/resource")
logger.warning("struct-test-warning", dta={"id": 1}, path="/path/to/resource")
logger.debug("struct-test-debug", data={"id": 1}, path="/path/to/resource")
logger.error("struct-test-error", data={"id": 1}, path="/path/to/resource")
# Out:
# 2024-11-19T07:43:14.667170Z [info     ] struct-test-info               [__main__] data={'id': 1} filename=3817302984.py lineno=2 path=/path/to/resource
# 2024-11-19T07:43:14.671665Z [warning  ] struct-test-warning            [__main__] dta={'id': 1} filename=3817302984.py lineno=3 path=/path/to/resource
# 2024-11-19T07:43:14.673115Z [error    ] struct-test-error              [__main__] data={'id': 1} filename=3817302984.py lineno=5 path=/path/to/resource

# %%
try:
    # 例外を発生させるコード
    raise UnicodeDecodeError("utf-8", b"", 1, 2, "test")
except Exception as e:
    logger.exception("StructLogUnicodeDecodeError", exc_info=True)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 try:                                                                                         │
# │   2 │   # 例外を発生させるコード                                                                 │
# │ ❱ 3 │   raise UnicodeDecodeError("utf-8", b"", 1, 2, "test")                                     │
# │   4 except Exception as e:                                                                       │
# │   5 │   logger.exception("StructLogUnicodeDecodeError", exc_info=True)                           │
# │   6                                                                                              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │                       _ = ''                                                                 │ │
# │ │                     _dh = [PosixPath('/Users/takeshiiijima/github/python_logger')]           │ │
# │ │                      _i = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+74               │ │
# │ │                     _i1 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+233                                             │ │
# │ │                    _i10 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                   _i100 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                   _i101 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                   _i102 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                   _i103 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                   _i104 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2700                                            │ │
# │ │                   _i105 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                   _i106 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                   _i107 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                   _i108 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+74               │ │
# │ │                   _i109 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i11 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2175                                            │ │
# │ │                    _i12 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i13 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i14 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2172                                            │ │
# │ │                    _i15 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i16 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i17 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2172                                            │ │
# │ │                    _i18 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i19 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                     _i2 = '# ロギング設定\nlogger =                                          │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295                                                   │ │
# │ │                    _i20 = '# try:\n#     # 例外を発生させるコード\n#     raise               │ │
# │ │                           ValueError()\n# except Exception as e:\n#  '+58                    │ │
# │ │                    _i21 = '# connection_string'                                              │ │
# │ │                    _i22 = '# import logging\n# import structlog\n# from                      │ │
# │ │                           azure.monitor.opentelemetry.exporter '+2116                        │ │
# │ │                    _i23 = '# # 使用例\n# struct_logger.info("struct-test-info", data={"id":  │ │
# │ │                           1}, path="/path/to/'+269                                           │ │
# │ │                    _i24 = '# struct_logger.info(\n#     "structlog-struct",\n#               │ │
# │ │                           data={"id": 1},\n#     path'+25                                    │ │
# │ │                    _i25 = '# try:\n#     1 / 0  # エラーを発生！\n# except                   │ │
# │ │                           ZeroDivisionError:\n#     struct_logger.ex'+89                     │ │
# │ │                    _i26 = '# import logging\n# import structlog\n# from                      │ │
# │ │                           azure.monitor.opentelemetry.exporter '+2671                        │ │
# │ │                    _i27 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i28 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i29 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                     _i3 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i30 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2172                                            │ │
# │ │                    _i31 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i32 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i33 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i34 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2173                                            │ │
# │ │                    _i35 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i36 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2171                                            │ │
# │ │                    _i37 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2237                                            │ │
# │ │                    _i38 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i39 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2235                                            │ │
# │ │                     _i4 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2175                                            │ │
# │ │                    _i40 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i41 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2171                                            │ │
# │ │                    _i42 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i43 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i44 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2173                                            │ │
# │ │                    _i45 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i46 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i47 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2171                                            │ │
# │ │                    _i48 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i49 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                     _i5 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i50 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+233                                             │ │
# │ │                    _i51 = '# ロギング設定\nlogger =                                          │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295                                                   │ │
# │ │                    _i52 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i53 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i54 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i55 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i56 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65               │ │
# │ │                    _i57 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i58 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2171                                            │ │
# │ │                    _i59 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                     _i6 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i60 = 'try:\n    raise NameError()\nexcept Exception as e:\n             │ │
# │ │                           logger.exception("struct-t'+41                                     │ │
# │ │                    _i61 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+233                                             │ │
# │ │                    _i62 = '# ロギング設定\nlogger =                                          │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295                                                   │ │
# │ │                    _i63 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+79               │ │
# │ │                    _i64 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+79               │ │
# │ │                    _i65 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2172                                            │ │
# │ │                    _i66 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i67 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i68 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i69 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2225                                            │ │
# │ │                     _i7 = 'import logging\nimport structlog\nfrom                            │ │
# │ │                           azure.monitor.opentelemetry.exporter import'+2529                  │ │
# │ │                    _i70 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i71 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2227                                            │ │
# │ │                    _i72 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i73 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2225                                            │ │
# │ │                    _i74 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i75 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i76 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i77 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2227                                            │ │
# │ │                    _i78 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i79 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                     _i8 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+233                                             │ │
# │ │                    _i80 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2449                                            │ │
# │ │                    _i81 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i82 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i83 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i84 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i85 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2448                                            │ │
# │ │                    _i86 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i87 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i88 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i89 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                     _i9 = '# ロギング設定\nlogger =                                          │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295                                                   │ │
# │ │                    _i90 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2448                                            │ │
# │ │                    _i91 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+231                                   │ │
# │ │                    _i92 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i93 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2574                                            │ │
# │ │                    _i94 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                    _i95 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2692                                            │ │
# │ │                    _i96 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                    _i97 = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _i98 = 'import os\nfrom dotenv import load_dotenv\nimport structlog\nfrom │ │
# │ │                           opencensus.ext.az'+2692                                            │ │
# │ │                    _i99 = '# 使用例\nlogger.info("struct-test-info", data={"id": 1},         │ │
# │ │                           path="/path/to/resource")\n'+230                                   │ │
# │ │                     _ih = [                                                                  │ │
# │ │                           │   '',                                                            │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+233,                            │ │
# │ │                           │   '# ロギング設定\nlogger =                                      │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295,                                                  │ │
# │ │                           │   'try:\n    # 例外を発生させるコード\n    raise                 │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65,              │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+2175,                           │ │
# │ │                           │   '# 使用例\nlogger.info("struct-test-info", data={"id": 1},     │ │
# │ │                           path="/path/to/resource")\n'+231,                                  │ │
# │ │                           │   'try:\n    raise NameError()\nexcept Exception as e:\n         │ │
# │ │                           logger.exception("struct-t'+41,                                    │ │
# │ │                           │   'import logging\nimport structlog\nfrom                        │ │
# │ │                           azure.monitor.opentelemetry.exporter import'+2529,                 │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+233,                            │ │
# │ │                           │   '# ロギング設定\nlogger =                                      │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295,                                                  │ │
# │ │                           │   ... +100                                                       │ │
# │ │                           ]                                                                  │ │
# │ │                     _ii = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                    _iii = 'try:\n    # 例外を発生させるコード\n    raise                     │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+89               │ │
# │ │                     _oh = {}                                                                 │ │
# │ │     azure_event_handler = <AzureEventHandler (NOTSET)>                                       │ │
# │ │         azure_formatter = <structlog.stdlib.ProcessorFormatter object at 0x1144c58a0>        │ │
# │ │           azure_handler = <AzureLogHandler (DEBUG)>                                          │ │
# │ │       AzureEventHandler = <class 'opencensus.ext.azure.log_exporter.AzureEventHandler'>      │ │
# │ │         AzureLogHandler = <class 'opencensus.ext.azure.log_exporter.AzureLogHandler'>        │ │
# │ │ AzureMonitorLogExporter = <class                                                             │ │
# │ │                           'azure.monitor.opentelemetry.exporter.export.logs._exporter.Azure… │ │
# │ │       connection_string = 'InstrumentationKey=a78b8b2e-cdf5-4ab4-ac67-6e13ebcda6bc;Ingestio… │ │
# │ │       console_formatter = <structlog.stdlib.ProcessorFormatter object at 0x111f656c0>        │ │
# │ │         console_handler = <StreamHandler stderr (INFO)>                                      │ │
# │ │                       e = UnicodeDecodeError('utf-8', b'', 1, 2, 'test')                     │ │
# │ │                    exit = <IPython.core.autocall.ZMQExitAutocall object at 0x10cfae650>      │ │
# │ │             get_ipython = <bound method InteractiveShell.get_ipython of                      │ │
# │ │                           <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10cfada20>>    │ │
# │ │                 handler = <StreamHandler stderr (NOTSET)>                                    │ │
# │ │                      In = [                                                                  │ │
# │ │                           │   '',                                                            │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+233,                            │ │
# │ │                           │   '# ロギング設定\nlogger =                                      │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295,                                                  │ │
# │ │                           │   'try:\n    # 例外を発生させるコード\n    raise                 │ │
# │ │                           UnicodeDecodeError("utf-8", b"", 1, 2, "test")\n'+65,              │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+2175,                           │ │
# │ │                           │   '# 使用例\nlogger.info("struct-test-info", data={"id": 1},     │ │
# │ │                           path="/path/to/resource")\n'+231,                                  │ │
# │ │                           │   'try:\n    raise NameError()\nexcept Exception as e:\n         │ │
# │ │                           logger.exception("struct-t'+41,                                    │ │
# │ │                           │   'import logging\nimport structlog\nfrom                        │ │
# │ │                           azure.monitor.opentelemetry.exporter import'+2529,                 │ │
# │ │                           │   'import os\nfrom dotenv import load_dotenv\nimport             │ │
# │ │                           structlog\nfrom opencensus.ext.az'+233,                            │ │
# │ │                           │   '# ロギング設定\nlogger =                                      │ │
# │ │                           logging.getLogger("ApplicationInsights")\nhandler =                │ │
# │ │                           AzureLogHan'+295,                                                  │ │
# │ │                           │   ... +100                                                       │ │
# │ │                           ]                                                                  │ │
# │ │             load_dotenv = <function load_dotenv at 0x10d1420e0>                              │ │
# │ │                  logger = <BoundLoggerLazyProxy(logger=None, wrapper_class=None,             │ │
# │ │                           processors=None, context_class=None, initial_values={},            │ │
# │ │                           logger_factory_args=())>                                           │ │
# │ │          LoggerProvider = <class 'opentelemetry._logs._internal.LoggerProvider'>             │ │
# │ │                 logging = <module 'logging' from                                             │ │
# │ │                           '/usr/local/Cellar/python@3.10/3.10.14/Frameworks/Python.framewor… │ │
# │ │                      os = <module 'os' from                                                  │ │
# │ │                           '/usr/local/Cellar/python@3.10/3.10.14/Frameworks/Python.framewor… │ │
# │ │                     Out = {}                                                                 │ │
# │ │                    quit = <IPython.core.autocall.ZMQExitAutocall object at 0x10cfae650>      │ │
# │ │                Resource = <class 'opentelemetry.sdk.resources.Resource'>                     │ │
# │ │     set_logger_provider = <function set_logger_provider at 0x1120d1750>                      │ │
# │ │      set_operation_name = <function set_operation_name at 0x114afe0e0>                       │ │
# │ │               structlog = <module 'structlog' from                                           │ │
# │ │                           '/usr/local/lib/python3.10/site-packages/structlog/__init__.py'>   │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 1-1: test
# 2024-11-19T07:53:46.634296Z [error    ] StructLogUnicodeDecodeError    [__main__] filename=561646677.py lineno=5

# %%
# try:
#     1 / 0  # エラーを発生！
# except ZeroDivisionError:
#     struct_logger.exception(
#         "structlog-structlog-structlog-structlog-error", exc_info=True
#     )
